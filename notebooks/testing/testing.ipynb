# %%
from core.rag import RAG
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from ingestion.image_captioner import VLMConfig
from retrieval.llm import LLMConfig


rag = RAG(
    storage_dir="./storage",
    postgres_url="postgresql://postgres:postgres@localhost:5432/postgres"
)

rag.set_llm(LLMConfig(provider = "ollama", model_name="llama3.2", base_url="http://localhost:11434/v1"))
rag.set_vlm(VLMConfig(provider="ollama", model_name="moondream", base_url="http://localhost:11434"))

# %%
from embedding.embedder import EmbedderConfig


rag.create_workspace(name="test", embedder_config=EmbedderConfig(provider = "ollama", model_name="nomic-embed-text"))
rag.select_workspace("test")

# %%
rag.add_document("./raw/2410.08143v2.pdf")
# Out:
# Skipping 2410.08143v2.pdf: Document already exists.
# UUID('62750725-dfa6-45ef-aae0-755c4e1fa411')

# %%
rag.retrieve_chunks("What metric quantifies consistent translation pairs among proper nouns?", 10)
# Out:
# [SearchResult(chunk_id=UUID('3a00ed8a-8f8b-4675-86ba-0c1ad53a2b56'), document_id=UUID('c398ae37-0820-4aef-aa47-9113c0de628a'), content='ic that quantifies the proportion of consistent translation pairs among all proper noun translation pairs in the target document. However, we argue that the translations of the proper nouns are supposed to not only maintain consistency throughout the document but also align their first appearance. This consid- eration is particularly important for enhancing the reading experience of audiences. Therefore, we introduce the LTCR-1 metric for the DocMT-LLMs, which calculates the proportion of proper noun translations that are consistent with the initial translation within the document:\n\nLTCR-1(Ds, Dt) =\n\nP\n\np∈P Pkp i=2 1(Ti(p) = T1(p)) P\n\np∈P (kp −1) (1)\n\nTi(p) represents the i-th translation of p in Dt, and kp denotes the number of occurrences of p in the document. The indicator function', metadata={}, score=0.8195887020055403),
# ...

# %%
rag.query("What metric quantifies consistent translation pairs among proper nouns?", 10)
# Out:
# 'The LTCR-1 (and its fuzzy version, LTCR-1f) metric quantifies the proportion of consistent translation pairs among proper nouns in the target document.'
