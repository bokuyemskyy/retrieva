# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

from retrieval.llm import LLMConfig
from ingestion.image_captioner import VLMConfig
from embedding.embedder import EmbedderConfig
from core.rag import RAG

load_dotenv()
# Out:
# True

# %%
rag = RAG(
    storage_dir="./storage",
    postgres_url="postgresql://postgres:postgres@localhost:5432/postgres"
)

llm = LLMConfig(
    provider="openai",
    model_name="gpt-4.1-mini",
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENAI_BASE_URL")
)

vlm = VLMConfig(
    provider="null",
    model_name="null"
)

embedder = EmbedderConfig(provider="openai", model_name="text-embedding-3-small")

workspace = "evaluation_practical1"

rag.create_workspace(
    name=workspace,
    embedder_config=embedder
)

# %%
RAW_DIR = Path("./raw")

pdf_paths = list(RAW_DIR.glob("*.pdf"))

rag.add_documents(workspace, [str(p) for p in pdf_paths])

print("Document ingestion complete")
# Out:
# Document ingestion complete

# %%
# rag.retrieve_chunks(workspace, "What is DFT", 5)
rag.query(workspace, "What is DFT", llm, 5, system_prompt= "Answer the question using only the provided context. "
"If the context does not contain enough information, say so.\n\n"
"Context:\n{context}\n\n"
"Question: {query}")
# rag.get_chunks()
# Out:
# 'DFT, or Density Functional Theory, is a method in quantum mechanics that reveals the existence of a universal functional of the total electron density, denoted as F[n(r)], which is independent of the external potential. Instead of dealing with the complex N-electron wave function, DFT uses a three-dimensional function of spatial coordinates (electron density), significantly reducing the complexity of the problem and scaling linearly with the system size. However, the exact form of this functional remains unknown, and the main practical challenge of DFT is finding an approximate form of this functional due to the complexity of the problem involving N interacting particles.'
