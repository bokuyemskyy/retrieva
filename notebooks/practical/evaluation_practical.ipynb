# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

from retrieval.llm import LLMConfig
from ingestion.image_captioner import VLMConfig
from embedding.embedder import EmbedderConfig
from core.rag import RAG

load_dotenv()
# Out:
# True

# %%
rag = RAG(
    storage_dir="./storage",
    postgres_url="postgresql://postgres:postgres@localhost:5432/postgres"
)

rag.set_llm(LLMConfig(
    provider="openai",
    model_name="gpt-4.1-mini",
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENAI_BASE_URL")
))

rag.set_vlm(VLMConfig(
    provider="null",
    model_name="null"
))

rag.create_workspace(
    name="evaluation_practical",
    embedder_config=EmbedderConfig(provider="openai", model_name="text-embedding-3-small")
)
rag.select_workspace("evaluation_practical")
# Out:
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %%
RAW_DIR = Path("./raw")

pdf_paths = list(RAW_DIR.glob("*.pdf"))

rag.add_documents([str(p) for p in pdf_paths])

print("Document ingestion complete")
# Out:
# Skipping QMQC - L6 - DFT.pdf: Document already exists.
# Skipping QMQC - L9-11 - Quantum gates.pdf: Document already exists.
# Skipping QMQC - L4-5.pdf: Document already exists.
# Skipping QMQC - L7-8 - Qubits.pdf: Document already exists.
# Skipping QMQC - L12-13 - Quantum algorithms.pdf: Document already exists.
# Skipping QMQC - L1.pdf: Document already exists.
# Skipping QMQC - L3.pdf: Document already exists.
# Skipping QMQC - L2.pdf: Document already exists.
# Document ingestion complete

# %%
# rag.retrieve_chunks("Which energy is there in DFT", 5)
rag.query("Explain Schrodinger Equation?", 5)
# rag.get_chunks()
# Out:
# 'The Schrödinger equation is a fundamental equation in quantum mechanics that describes how the quantum state of a physical system changes. It can be time-dependent or time-independent. \n\n- The time-independent Schrödinger equation (TISE) is an ordinary differential equation in one spatial dimension and serves as an eigenvalue equation for the Hamiltonian operator, expressed as:\n\n  \\(\\hat{H} \\psi = E \\psi\\)\n\n  where \\(\\hat{H}\\) is the Hamiltonian operator, \\(\\psi\\) is the spatial part of the wavefunction, and \\(E\\) is the energy eigenvalue.\n\n- The general solution to the Schrödinger equation for a particle in a box is:\n\n  \\(\\psi(x) = A \\sin(kx) + B \\cos(kx)\\)\n\n  where \\(A\\) and \\(B\\) are constants determined by boundary and normalization conditions.\n\n- For a particle confined in a box of length \\(L\\), the boundary conditions require the wavefunction to be zero at the walls (\\(\\psi(0) = \\psi(L) = 0\\)), leading to \\(B=0\\) and quantization of the wave number \\(k\\) such that:\n\n  \\(kL = n\\pi\\), where \\(n = \\pm 1, \\pm 2, ...\\)\n\n- This quantization leads to discrete energy levels given by:\n\n  \\(E_n = \\frac{n^2 \\pi^2 \\hbar^2}{2 m L^2}\\)\n\nIn summary, the Schrödinger equation provides a way to calculate the allowed energy levels and corresponding wavefunctions of quantum systems, such as a particle confined in a box, by solving an eigenvalue problem with appropriate boundary conditions.'
